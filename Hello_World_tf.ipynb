# %% [markdown]
# <a href="https://colab.research.google.com/github/mohsen-jr/Tensorflow_developer/blob/main/Hello_World_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
print(tf.__version__)
# Out:
# 2.8.2

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Declare model inputs and outputs for training
Xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
Ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(Xs, Ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.5565e-05
# Epoch 2/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.4217e-05
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.2898e-05
# Epoch 4/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.1605e-05
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0340e-05
# Epoch 6/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9101e-05
# Epoch 7/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.7888e-05
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.6698e-05
# Epoch 9/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5532e-05
# Epoch 10/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4392e-05
# Epoch 11/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3275e-05
# Epoch 12/1000
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Make a prediction
print(model.predict([15.0]))
# Out:
# [[28.999977]]
